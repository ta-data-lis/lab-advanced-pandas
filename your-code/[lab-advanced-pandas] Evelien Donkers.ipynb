# %% [markdown]
# # Before your start:
# - Read the README.md file
# - Comment as much as you can and use the resources (README.md file)
# - Happy learning!

# %%
from scipy import stats
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns
sns.set()
from sklearn.linear_model import LogisticRegression

# %% [markdown]
# # Challenge 1 - Index Functions
#
# In this challenge, we will practice the advanced functions introduced in the lesson. However, before we start, we will load and evaluate our dataset.
#
# Load the dataset from Ironhack's database:
# * db: `admissions predict`
# * table: `admissions predict`

# %%
admissions = df2 = df = pd.read_csv('Admission_Predict.csv')

# %% [markdown]
# Remove trailing spaces at the end of the column names if there are any.

# %%
df3 = df.columns = df.columns.str.replace(' ', '')

# %% [markdown]
# Let's evaluate the dataset by looking at the `head` function.

# %%
df.head()
# Out:
#    SerialNo.  GREScore  TOEFLScore  UniversityRating  SOP  LOR  CGPA  \
# 0          1       337         118                 4  4.5  4.5  9.65
# 1          2       316         104                 3  3.0  3.5  8.00
# 2          3       322         110                 3  3.5  2.5  8.67
# 3          4       314         103                 2  2.0  3.0  8.21
# 4          5       330         115                 5  4.5  3.0  9.34
#
#    Research  ChanceofAdmit
# 0         1           0.92
# 1         1           0.72
# 2         1           0.80
# 3         0           0.65
# 4         1           0.90

# %% [markdown]
# Before beginning to work with this dataset and evaluating graduate admissions data, we will verify that there is no missing data in the dataset. Do this in the cell below.

# %%
###No missing data while verything is 385

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 385 entries, 0 to 384
# Data columns (total 9 columns):
# SerialNo.           385 non-null int64
# GREScore            385 non-null int64
# TOEFLScore          385 non-null int64
# UniversityRating    385 non-null int64
# SOP                 385 non-null float64
# LOR                 385 non-null float64
# CGPA                385 non-null float64
# Research            385 non-null int64
# ChanceofAdmit       385 non-null float64
# dtypes: float64(4), int64(5)
# memory usage: 27.1 KB

# %% [markdown]
# Interestingly, there is a column that uniquely identifies the applicants. This column is the serial number column. Instead of having our own index, we should make this column our index. Do this in the cell below. Keep the column in the dataframe in addition to making it an index.

# %%
df.set_index('SerialNo.', inplace=True)

# %% [markdown]
# Turns out that `GRE Score` and `CGPA` also uniquely identify the data. Show this in the cell below.

# %%
pd.Series(['CGPA']).is_unique
# Out:
# True

# %%
pd.Series(['GREScore']).is_unique
# Out:
# True

# %%
df['CGPA'].apply(str)
df['GREScore'].apply(str)
# Out:
# SerialNo.
# 1      337
# 2      316
# 3      322
# 4      314
# 5      330
# 6      321
# 7      308
# 8      302
# 9      323
# 10     327
# 11     328
# 12     307
# 13     311
# 14     314
# 15     317
# 16     319
# 17     318
# 18     303
# 19     325
# 20     328
# 21     334
# 22     336
# 23     322
# 24     298
# 25     295
# 26     310
# 27     300
# 28     327
# 29     338
# 30     340
#       ...
# 356    310
# 357    324
# 358    336
# 359    321
# 360    315
# 361    304
# 362    297
# 363    290
# 364    303
# 365    311
# 366    322
# 367    319
# 368    324
# 369    300
# 370    340
# 371    335
# 372    302
# 373    307
# 374    296
# 375    320
# 376    314
# 377    318
# 378    326
# 379    317
# 380    329
# 381    324
# 382    325
# 383    330
# 384    312
# 385    333
# Name: GREScore, Length: 385, dtype: object

# %%
df["Unique"] = df['CGPA'].apply(str) + df['GREScore'].apply(str)
df.head()
# Out:
#            GREScore  TOEFLScore  UniversityRating  SOP  LOR  CGPA  Research  \
# SerialNo.
# 1               337         118                 4  4.5  4.5  9.65         1
# 2               316         104                 3  3.0  3.5  8.00         1
# 3               322         110                 3  3.5  2.5  8.67         1
# 4               314         103                 2  2.0  3.0  8.21         0
# 5               330         115                 5  4.5  3.0  9.34         1
#
#            ChanceofAdmit   Unique
# SerialNo.
# 1                   0.92  9.65337
# 2                   0.72   8.0316
# 3                   0.80  8.67322
# 4                   0.65  8.21314
# 5                   0.90  9.34330

# %%
df = df.drop(columns=['GREScore', 'CGPA'])

# %% [markdown]
# Replace the index with an index comprised of two columns - `GRE Score` and `CGPA`. Remove the columns from the dataset as well. Make sure to use `inplace=True`.

# %%
df.set_index('Unique', inplace=True)

# %%
df.head()
# Out:
#          TOEFLScore  UniversityRating  SOP  LOR  Research  ChanceofAdmit
# Unique
# 9.65337         118                 4  4.5  4.5         1           0.92
# 8.0316          104                 3  3.0  3.5         1           0.72
# 8.67322         110                 3  3.5  2.5         1           0.80
# 8.21314         103                 2  2.0  3.0         0           0.65
# 9.34330         115                 5  4.5  3.0         1           0.90

# %% [markdown]
# Now change the index back to a sequence starting at zero using the `reset_index` function. Make sure to use `inplace=True`.

# %%
df.reset_index()
# Out:
#       Unique  TOEFLScore  UniversityRating  SOP  LOR  Research  ChanceofAdmit
# 0    9.65337         118                 4  4.5  4.5         1           0.92
# 1     8.0316         104                 3  3.0  3.5         1           0.72
# 2    8.67322         110                 3  3.5  2.5         1           0.80
# 3    8.21314         103                 2  2.0  3.0         0           0.65
# 4    9.34330         115                 5  4.5  3.0         1           0.90
# 5     8.2321         109                 3  3.0  4.0         1           0.75
# 6     7.9308         101                 2  3.0  4.0         0           0.68
# 7     8.0302         102                 1  2.0  1.5         0           0.50
# 8     8.6323         108                 3  3.5  3.0         0           0.45
# 9     9.0327         111                 4  4.0  4.5         1           0.84
# 10    9.1328         112                 4  4.0  4.5         1           0.78
# ...

# %% [markdown]
# # Challenge 2 - Advanced Functions
#
# In this part of the lab, we would like to test complex conditions on the entire dataset at once. Let's start by finding the number of rows where the CGPA is higher than 9 and the student has conducted research.

# %%
df2[(df2['CGPA'] > 9) & (df2['Research'] == 1)]

###101 rows.
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0             1        337          118                  4  4.5   4.5  9.65
# 4             5        330          115                  5  4.5   3.0  9.34
# 10           11        328          112                  4  4.0   4.5  9.10
# 19           20        328          116                  5  5.0   5.0  9.50
# 20           21        334          119                  5  5.0   4.5  9.70
# 21           22        336          119                  5  4.0   3.5  9.80
# 28           29        338          118                  4  3.0   4.5  9.40
# 29           30        340          114                  5  4.0   4.0  9.60
# 30           31        331          112                  5  4.0   5.0  9.80
# 31           32        320          110                  5  5.0   5.0  9.20
# 40           41        326          113                  5  4.5   4.0  9.40
# ...

# %% [markdown]
# Now return all the rows where the CGPA is greater than 9 and the SOP score is less than 3.5. Find the mean chance of admit for these applicants.

# %%
df2['ChanceofAdmit'] = df2['ChanceofAdmit'].astype(float)
df2
# Out:
#      SerialNo.  GREScore  TOEFLScore  UniversityRating  SOP  LOR  CGPA  \
# 0            1       337         118                 4  4.5  4.5  9.65
# 1            2       316         104                 3  3.0  3.5  8.00
# 2            3       322         110                 3  3.5  2.5  8.67
# 3            4       314         103                 2  2.0  3.0  8.21
# 4            5       330         115                 5  4.5  3.0  9.34
# 5            6       321         109                 3  3.0  4.0  8.20
# 6            7       308         101                 2  3.0  4.0  7.90
# 7            8       302         102                 1  2.0  1.5  8.00
# 8            9       323         108                 3  3.5  3.0  8.60
# 9           10       327         111                 4  4.0  4.5  9.00
# 10          11       328         112                 4  4.0  4.5  9.10
# 11          12       307         109                 3  4.0  3.0  8.00
# ...

# %%
df3 = df2[(df2['CGPA'] > 9) & (df2['SOP'] < 3.5)]
df3
# Out:
#      SerialNo.  GREScore  TOEFLScore  UniversityRating  SOP  LOR  CGPA  \
# 28          29       338         118                 4  3.0  4.5  9.40
# 62          63       327         114                 3  3.0  3.0  9.02
# 140        141       326         114                 3  3.0  3.0  9.11
# 217        218       324         111                 4  3.0  3.0  9.01
# 381        382       325         107                 3  3.0  3.5  9.11
#
#      Research  ChanceofAdmit
# 28          1           0.91
# 62          0           0.61
# 140         1           0.83
# 217         1           0.82
# 381         1           0.84

# %%
df3.mean()
## it would be 0.802
# Out:
# SerialNo.           166.600
# GREScore            328.000
# TOEFLScore          112.800
# UniversityRating      3.400
# SOP                   3.000
# LOR                   3.400
# CGPA                  9.130
# Research              0.800
# ChanceofAdmit         0.802
# dtype: float64

# %% [markdown]
# We would like to create a deciding factor column for each student. We standardize several columns and then pick the most important factor from a lookup table. If the standardized value is above 0.8, the student will be accepted.
#
# We will start by creating a standardized column for `CGPA`, `GRE Score` and `LOR`. We will name these columns `CGPA_std`, `GRE_std`, and `LOR_std` respecively.
#
# Recall that standardizing a column is done by subtracting the mean of the column from all observations in the column and then dividing each observation in the column by the column's standard deviation.
#
# In the cell below, write a standardization function (a function that takes a column as input and returns a standardized column as output). Make sure to use the `numpy` versions of mean and standard deviation.

# %%
from sklearn.preprocessing import StandardScaler

def standardize(col):
    df[col] = StandardScaler().fit_transform(df[col])

# %%
df.columns
# Out:
# Index(['Serial No.', 'GRE Score', 'TOEFL Score', 'University Rating', 'SOP',
#        'LOR ', 'CGPA', 'Research', 'Chance of Admit '],
#       dtype='object')

# %%
df['CGPA_std'] = df['CGPA']
df['GRE_std'] = df['GRE Score']
df['LOR_std'] = df['LOR ']

# %%
standardize(['CGPA_std'])
standardize(['GRE_std'])
standardize(['LOR_std'])

df
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0             1        337          118                  4  4.5   4.5  9.65
# 1             2        316          104                  3  3.0   3.5  8.00
# 2             3        322          110                  3  3.5   2.5  8.67
# 3             4        314          103                  2  2.0   3.0  8.21
# 4             5        330          115                  5  4.5   3.0  9.34
# 5             6        321          109                  3  3.0   4.0  8.20
# 6             7        308          101                  2  3.0   4.0  7.90
# 7             8        302          102                  1  2.0   1.5  8.00
# 8             9        323          108                  3  3.5   3.0  8.60
# 9            10        327          111                  4  4.0   4.5  9.00
# 10           11        328          112                  4  4.0   4.5  9.10
# ...

# %% [markdown]
# Now create the standardized columns `CGPA_std`, `GRE_std`, and `LOR_std` and add them to the `admissions` dataframe.

# %% [markdown]
# We will generate the decision choice at random using the code below. Please run the cell.

# %%
# Libraries
from random import choices

# %%
std_columns = ['CGPA_std', 'GRE_std', 'LOR_std']

decision_choice = choices(std_columns, k=admissions.shape[0])
decision_choice
# Out:
# ['GRE_std',
#  'LOR_std',
#  'GRE_std',
#  'CGPA_std',
#  'LOR_std',
#  'LOR_std',
#  'GRE_std',
#  'LOR_std',
#  'LOR_std',
#  'LOR_std',
#  'CGPA_std',
#  'LOR_std',
#  'LOR_std',
#  'LOR_std',
#  'LOR_std',
#  'CGPA_std',
#  'GRE_std',
#  'CGPA_std',
#  'GRE_std',
#  'GRE_std',
#  'LOR_std',
#  'CGPA_std',
#  'LOR_std',
#  'LOR_std',
#  'LOR_std',
#  'GRE_std',
#  'CGPA_std',
#  'LOR_std',
#  'CGPA_std',
#  'LOR_std',
#  'CGPA_std',
#  'CGPA_std',
#  'GRE_std',
#  'GRE_std',
#  'LOR_std',
#  'GRE_std',
#  'GRE_std',
#  'CGPA_std',
#  'LOR_std',
#  'GRE_std',
#  'GRE_std',
#  'LOR_std',
#  'CGPA_std',
#  'GRE_std',
#  'GRE_std',
#  'CGPA_std',
#  'CGPA_std',
#  'GRE_std',
#  'LOR_std',
#  'CGPA_std',
#  'LOR_std',
#  'LOR_std',
#  'LOR_std',
#  'GRE_std',
#  'LOR_std',
#  'LOR_std',
#  'LOR_std',
#  'CGPA_std',
#  'CGPA_std',
#  'GRE_std',
#  'LOR_std',
#  'CGPA_std',
#  'GRE_std',
#  'GRE_std',
#  'CGPA_std',
#  'CGPA_std',
#  'GRE_std',
#  'CGPA_std',
#  'LOR_std',
#  'GRE_std',
# ...

# %% [markdown]
# Now create the deciding column using the `lookup` function. The lookup column is `decision_choice` found above. Call the column resulting from the lookup function `deciding_column` and add it to the `admissions` dataframe.

# %%
df['deciding_column'] = df.lookup(df.index, decision_choice)
df.head()
# Out:
#    Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0           1        337          118                  4  4.5   4.5  9.65
# 1           2        316          104                  3  3.0   3.5  8.00
# 2           3        322          110                  3  3.5   2.5  8.67
# 3           4        314          103                  2  2.0   3.0  8.21
# 4           5        330          115                  5  4.5   3.0  9.34
#
#    Research  Chance of Admit   CGPA_std   GRE_std   LOR_std  deciding_column
# 0         1              0.92  1.750174  1.755663  1.193197         1.755663
# 1         1              0.72 -0.992501 -0.063450  0.076840         0.076840
# 2         1              0.80  0.121191  0.456297 -1.039517         0.456297
# 3         0              0.65 -0.643433 -0.236698 -0.481338        -0.643433
# 4         1              0.90  1.234884  1.149292 -0.481338        -0.481338

# %%
df['decision'] = np.where(df['deciding_column'] >0.8, 1, 0)
df
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0             1        337          118                  4  4.5   4.5  9.65
# 1             2        316          104                  3  3.0   3.5  8.00
# 2             3        322          110                  3  3.5   2.5  8.67
# 3             4        314          103                  2  2.0   3.0  8.21
# 4             5        330          115                  5  4.5   3.0  9.34
# 5             6        321          109                  3  3.0   4.0  8.20
# 6             7        308          101                  2  3.0   4.0  7.90
# 7             8        302          102                  1  2.0   1.5  8.00
# 8             9        323          108                  3  3.5   3.0  8.60
# 9            10        327          111                  4  4.0   4.5  9.00
# 10           11        328          112                  4  4.0   4.5  9.10
# ...

# %% [markdown]
# Create a column called `decision` in the `admissions` dataframe. Assign 1 to this column if the value of `deciding_column` is greater than 0.8 and 0 otherwise.

# %% [markdown]
# How many applicants will be accepted to the program using the decision column? Compute the result below.

# %%
df['decision'].sum()
# Out:
# 93

# %% [markdown]
# # Challenge 3 - Method Chaining
#
# To increase our coding efficiency, let's make a number of changes to our dataframe in one line of code.
#
# In the cell below, remove all non character symbols from the column names, replace all spaces in column names to underscores, and change all upper case characters to lower case. Assign these new column values to `admissions.columns`.

# %%
df = df.replace('[^a-zA-Z0-9]', '', regex=True).columns.str.replace(' ', '').str.replace('.', '').str.lower()

# %% [markdown]
# In the cell below, give all student with a university rating of 4 or higher a 10 point boost on their GRE score and split the column into 4 bins using the `cut` function. Assign this new score to the variable `adjusted_gre`.

# %%
adjusted_gre = pd.cut(np.where(df["universityrating"]>=4, df["grescore"]+10, df["grescore"]),bins=4)
adjusted_gre
